# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1) 데이터 전처리

# %% [markdown]
# ### - 필요한 데이터 excel파일 불러오기 : pd.read_excel

# %% [markdown]
# - 활용데이터 : <공공도서관 통계결과표(17~21년)>

# %%
p19=pd.read_excel('data/Public_data_2019.xlsx')

# %%
#칼럼명 확인
p19.columns
# Out:
# Index(['도서관코드', '도서관명', '구분', '지역', '지역_시군구', '설립주체', '설립주체_기관명', '운영방식',
#        '운영기관명', '분관내용',
#        ...
#        '지식취약_예산_노인', '지식취약_예산_다문화', '어린이실_유무', '어린이실_이용자수', '어린이실_인쇄자료수',
#        '어린이실_연간증가자료수', '메타데이터_도서자료', '메타데이터_연속간행물', '메타데이터_비도서', '메타데이터_기타'],
#       dtype='object', length=242)

# %% [markdown]
# ### - 필요데이터 칼럼 구분하여 데이터프레임 형성

# %%
p19a=p19.loc[:,['도서관명', '구분', '지역','시설_연면적','개관일수', '평균개관시간', '회원등록자수_어린이', '회원등록자수_청소년', '회원등록자수_성인', '도서관_방문자수']]
#2-1)이름/공공/지역/면적/개관일,시간/나이별등록자수/총방문자수

# %%
p19b=p19.loc[:,['작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수']]
##0.0공공->작은지원내역

# %%
p19c=p19.loc[:,['결산_인건비_금액','결산_인건비_비고','결산_자료구입비_금액','결산_자료구입비_비고','결산_운영비_금액','결산_운영비_비고']]
#공공예산사용내역

# %%
p19d=p19.loc[:,['예산_자료구입비_도서_금액','예산_자료구입비_비도서_금액','예산_자료구입비_전자_금액','예산_자료구입비_연속_금액','예산_운영비_유지비_금액','예산_운영비_프로그램비_금액','예산_운영비_기타_금액']]
#예산 중 자료구입내역

# %%
p19e=p19.loc[:,['도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','향토_향토자료','향토_기타','비도서_시청각자료','비도서_기타자료','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외']]
#장서분석[십진분류][도서:국내/국외/향토, 비도서:시청각/기타, 전자:저널,도서,기타 연속]

# %%
p19f=p19.loc[:,['대출자수_어린이','대출자수_청소년','대출자수_성인']]
#2-2 이용자 분석 나이별 대출자수

# %%
p19g=p19.loc[:,['대출권수_어린이_총류','대출권수_어린이_철학','대출권수_어린이_종교','대출권수_어린이_사회과학','대출권수_어린이_순수과학','대출권수_어린이_기술과학','대출권수_어린이_예술','대출권수_어린이_언어','대출권수_어린이_문학','대출권수_어린이_역사','대출권수_청소년_총류','대출권수_청소년_철학','대출권수_청소년_종교','대출권수_청소년_사회과학','대출권수_청소년_순수과학','대출권수_청소년_기술과학','대출권수_청소년_예술','대출권수_청소년_언어','대출권수_청소년_문학','대출권수_청소년_역사','대출권수_성인_총류','대출권수_성인_철학','대출권수_성인_종교','대출권수_성인_사회과학','대출권수_성인_순수과학','대출권수_성인_기술과학','대출권수_성인_예술','대출권수_성인_언어','대출권수_성인_문학','대출권수_성인_역사']]
#2-2 이용자 분석: 나이/장르/자료별 대출권수

# %%
p19h=p19.loc[:,['상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지접속건수','모바일웹접속건수','이용자교육_회수','이용자교육_시간','이용자교육_참가자수','문화프로그램_강좌_횟수','문화프로그램_강좌_참가자수','문화프로그램_1회_횟수','문화프로그램_1회_참가자수','도서프로그램_강좌_횟수','도서프로그램_강좌_참가자수','도서프로그램_1회_횟수','도서프로그램_1회_참가자수']]
#도서 운영프로그램 및 서비스

# %%
p19i=p19.loc[:,'도서관총예산']

# %% [markdown]
# ### - 시범 데이터프레임 제작 후 나머지 파일에도 동일한 작업 실행

# %%
p21=pd.read_excel('data/Public_data_2021.xlsx')

# %%
p20=pd.read_excel('data/Public_data_2020.xlsx')

# %%
p18=pd.read_excel('data/Public_data_2018.xlsx')

# %%
p17=pd.read_excel('data/Public_data_2017.xlsx')

# %%
p18a=p18.loc[:,['도서관명','구분','지역','시설_연면적','개관일수','평균개관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인','도서관_방문자수']]
#2-1)이름/공공/지역/면적/개관일,시간/나이별등록자수/총방문자수
p18b=p18.loc[:,['작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수']]
##0.0공공->작은지원내역
p18c=p18.loc[:,['결산_인건비_금액','결산_인건비_비고','결산_자료구입비_금액','결산_자료구입비_비고','결산_운영비_금액','결산_운영비_비고']]
#공공예산사용내역
p18d=p18.loc[:,['예산_자료구입비_도서_금액','예산_자료구입비_비도서_금액','예산_자료구입비_전자_금액','예산_자료구입비_연속_금액','예산_운영비_유지비_금액','예산_운영비_프로그램비_금액','예산_운영비_기타_금액']]
#예산 중 자료구입내역
p18e=p18.loc[:,['도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','향토_향토자료','향토_기타','비도서_시청각자료','비도서_기타자료','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외']]
#장서분석[십진분류][도서:국내/국외/향토, 비도서:시청각/기타, 전자:저널,도서,기타 연속]
p18f=p18.loc[:,['대출자수_어린이','대출자수_청소년','대출자수_성인']]
#2-2 이용자 분석 나이별 대출자수
p18g=p18.loc[:,['대출권수_어린이_총류','대출권수_어린이_철학','대출권수_어린이_종교','대출권수_어린이_사회과학','대출권수_어린이_순수과학','대출권수_어린이_기술과학','대출권수_어린이_예술','대출권수_어린이_언어','대출권수_어린이_문학','대출권수_어린이_역사','대출권수_청소년_총류','대출권수_청소년_철학','대출권수_청소년_종교','대출권수_청소년_사회과학','대출권수_청소년_순수과학','대출권수_청소년_기술과학','대출권수_청소년_예술','대출권수_청소년_언어','대출권수_청소년_문학','대출권수_청소년_역사','대출권수_성인_총류','대출권수_성인_철학','대출권수_성인_종교','대출권수_성인_사회과학','대출권수_성인_순수과학','대출권수_성인_기술과학','대출권수_성인_예술','대출권수_성인_언어','대출권수_성인_문학','대출권수_성인_역사']]
#2-2 이용자 분석: 나이/장르/자료별 대출권수
p18h=p18.loc[:,['상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지접속건수','모바일웹접속건수','이용자교육_회수','이용자교육_시간','이용자교육_참가자수','문화프로그램_강좌_횟수','문화프로그램_강좌_참가자수','문화프로그램_1회_횟수','문화프로그램_1회_참가자수','도서프로그램_강좌_횟수','도서프로그램_강좌_참가자수','도서프로그램_1회_횟수','도서프로그램_1회_참가자수']]
#도서 운영프로그램 및 서비스
p18i=p18.loc[:,'도서관총예산']

# %%
p17a=p17.loc[:,['도서관명', '구분', '지역','시설_연면적','개관일수', '평균개관시간', '회원등록자수_어린이', '회원등록자수_청소년', '회원등록자수_성인', '도서관_방문자수']]
#2-1)이름/공공/지역/면적/개관일,시간/나이별등록자수/총방문자수
p17b=p17.loc[:,['작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수']]
##0.0공공->작은지원내역
p17c=p17.loc[:,['결산_인건비_금액','결산_인건비_비고','결산_자료구입비_금액','결산_자료구입비_비고','결산_운영비_금액','결산_운영비_비고']]
#공공예산사용내역
p17d=p17.loc[:,['예산_자료구입비_도서_금액','예산_자료구입비_비도서_금액','예산_자료구입비_전자_금액','예산_자료구입비_연속_금액','예산_운영비_유지비_금액','예산_운영비_프로그램비_금액','예산_운영비_기타_금액']]
#예산 중 자료구입내역
p17e=p17.loc[:,['도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','향토_향토자료','향토_기타','비도서_시청각자료','비도서_기타자료','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외']]
#장서분석[십진분류][도서:국내/국외/향토, 비도서:시청각/기타, 전자:저널,도서,기타 연속]
p17f=p17.loc[:,['대출자수_어린이','대출자수_청소년','대출자수_성인']]
#2-2 이용자 분석 나이별 대출자수
p17g=p17.loc[:,['대출권수_어린이_총류','대출권수_어린이_철학','대출권수_어린이_종교','대출권수_어린이_사회과학','대출권수_어린이_순수과학','대출권수_어린이_기술과학','대출권수_어린이_예술','대출권수_어린이_언어','대출권수_어린이_문학','대출권수_어린이_역사','대출권수_청소년_총류','대출권수_청소년_철학','대출권수_청소년_종교','대출권수_청소년_사회과학','대출권수_청소년_순수과학','대출권수_청소년_기술과학','대출권수_청소년_예술','대출권수_청소년_언어','대출권수_청소년_문학','대출권수_청소년_역사','대출권수_성인_총류','대출권수_성인_철학','대출권수_성인_종교','대출권수_성인_사회과학','대출권수_성인_순수과학','대출권수_성인_기술과학','대출권수_성인_예술','대출권수_성인_언어','대출권수_성인_문학','대출권수_성인_역사']]
#2-2 이용자 분석: 나이/장르/자료별 대출권수
p17h=p17.loc[:,['상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지접속건수','모바일웹접속건수','이용자교육_회수','이용자교육_시간','이용자교육_참가자수','문화프로그램_강좌_횟수','문화프로그램_강좌_참가자수','문화프로그램_1회_횟수','문화프로그램_1회_참가자수','도서프로그램_강좌_횟수','도서프로그램_강좌_참가자수','도서프로그램_1회_횟수','도서프로그램_1회_참가자수']]
#도서 운영프로그램 및 서비스
p17i=p17.loc[:,'도서관총예산']

# %%
p20a=p20.loc[:,['도서관명', '구분', '지역','시설_도서관부지면적','연간_총_개관일수','주당_평균_개관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인','회원등록자수_가족단위','도서관_방문자수']]
#2-1)이름/공공/지역
p20b=p20.loc[:,['작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수']]
##0.0공공->작은지원내역
p20c=p20.loc[:,['결산_인건비_금액(천원)','결산_인건비_비고','결산_자료구입비_금액(천원)','결산_자료구입비_비고','결산_운영비_금액(천원)','결산_운영비_비고']]
#공공예산사용내역
p20d=p20.loc[:,['예산_자료구입비_도서_금액(천원)','예산_자료구입비_비도서_금액(천원)','예산_자료구입비_전자_금액(천원)','예산_자료구입비_연속_금액(천원)','예산_운영비_유지비_금액(천원)','예산_운영비_프로그램비_금액(천원)','예산_운영비_기타_금액(천원)']]
#예산 중 자료구입내역
p20e=p20.loc[:,['도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사
p21a=p21.loc[:,['도서관명', '구분', '지역','면적_도서관부지면적','일수및시간_연간총개관일수','일수및시간_주당평균개관시간','회원등록자수_연령별회원등록_어린이','회원등록자수_연령별회원등록_청소년','회원등록자수_연령별회원등록_성인','가족단위회원등록자수','이용자수_도서관방문자수']]
#2-1)이름/공공/지역
p21b=p21.loc[:,['작은도서관_협력도서관수','작은도서관_협력인력수','작은도서관_협력예산액','작은도서관_협력장서수','작은도서관_협력프로그램수']]
##0.0공공->작은지원내역
p21c=p21.loc[:,['결산액_인건비_금액(천원)','결산액_인건비_비고','결산액_자료구입비_금액(천원)','결산액_자료구입비_비고','결산액_운영비_금액(천원)','결산액_운영비_비고']]
#공공예산사용내역
p21d=p21.loc[:,['도서관총예산_자료구입비_도서자료구입비_금액(천원)','도서관총예산_자료구입비_비도서구입비_금액(천원)','도서관총예산_자료구입비_전자자료구입비_금액(천원)','도서관총예산_자료구입비_연속간행물_금액(천원)','도서관총예산_운영비_원문DB구축및정보화관련개발유지비_금액(천원)','도서관총예산_운영비_프로그램운영비_금액(천원)','도서관총예산_운영비_기타사업비총액_금액(천원)']]
#예산 중 자료구입내역
p21e=p21.loc[:,['도서(인쇄)자료수_국내서_총류','도서(인쇄)자료수_국내서_철학','도서(인쇄)자료수_국내서_종교','도서(인쇄)자료수_국내서_사회과학','도서(인쇄)자료수_국내서_순수과학','도서(인쇄)자료수_국내서_기술과학','도서(인쇄)자료수_국내서_예술','도서(인쇄)자료수_국내서_언어','도서(인쇄)자료수_국내서_문학','도서(인쇄)자료수_국내서_역사','도서(인쇄)자료수_국외서_총류','도서(인쇄)자료수_국외서_철학','도서(인쇄)자료수_국외서_종교','도서(인쇄)자료수_국외서_사회과학','도서(인쇄)자료수_국외서_순수과학','도서(인쇄)자료수_국외서_기술과학','도서(인쇄)자료수_국외서_예술','도서(인쇄)자료수_국외서_언어','도서(인쇄)자료수_국외서_문학','도서(인쇄)자료수_국외서_역사','지역자료수_국내_지역자료','지역자료수_국내_기타','비도서자료수_국내외_시청각자료','비도서자료수_국내외_기타','전자자료수_국내외_전자저널','전자자료수_국내외_전자도서','전자자료수_국내외_오디오북','전자자료수_국내외_기타','연속간행물(인쇄자료)수_국내','연속간행물(인쇄자료)수_국외']]
#장서분석[십진분류][도서:국내/국외/향토, 비도서:시청각/기타, 전자:저널,도서,오디오,기타, 연속간행물, 연간제적]
p21f=p21.loc[:,['대출자수_인쇄자료_어린이','대출자수_인쇄자료_청소년','대출자수_인쇄자료_성인','대출자수_전자자료_어린이','대출자수_전자자료_청소년','대출자수_전자자료_성인']]
#2-2 이용자 분석 나이별 대출자수
p21g=p21.loc[:,['대출권수_인쇄자료_어린이_총류','대출권수_인쇄자료_어린이_철학','대출권수_인쇄자료_어린이_종교','대출권수_인쇄자료_어린이_사회과학','대출권수_인쇄자료_어린이_순수과학','대출권수_인쇄자료_어린이_기술과학','대출권수_인쇄자료_어린이_예술','대출권수_인쇄자료_어린이_언어','대출권수_인쇄자료_어린이_문학','대출권수_인쇄자료_어린이_역사','대출권수_인쇄자료_청소년_총류','대출권수_인쇄자료_청소년_철학','대출권수_인쇄자료_청소년_종교','대출권수_인쇄자료_청소년_사회과학','대출권수_인쇄자료_청소년_순수과학','대출권수_인쇄자료_청소년_기술과학','대출권수_인쇄자료_청소년_예술','대출권수_인쇄자료_청소년_언어','대출권수_인쇄자료_청소년_문학','대출권수_인쇄자료_청소년_역사','대출권수_인쇄자료_성인_총류','대출권수_인쇄자료_성인_철학','대출권수_인쇄자료_성인_종교','대출권수_인쇄자료_성인_사회과학','대출권수_인쇄자료_성인_순수과학','대출권수_인쇄자료_성인_기술과학','대출권수_인쇄자료_성인_예술','대출권수_인쇄자료_성인_언어','대출권수_인쇄자료_성인_문학','대출권수_인쇄자료_성인_역사']]
p21ge=p21.loc[:,['대출권수_전자자료_어린이_총류','대출권수_전자자료_어린이_철학','대출권수_전자자료_어린이_종교','대출권수_전자자료_어린이_사회과학','대출권수_전자자료_어린이_순수과학','대출권수_전자자료_어린이_기술과학','대출권수_전자자료_어린이_예술','대출권수_전자자료_어린이_언어','대출권수_전자자료_어린이_문학','대출권수_전자자료_어린이_역사','대출권수_전자자료_청소년_총류','대출권수_전자자료_청소년_철학','대출권수_전자자료_청소년_종교','대출권수_전자자료_청소년_사회과학','대출권수_전자자료_청소년_순수과학','대출권수_전자자료_청소년_기술과학','대출권수_전자자료_청소년_예술','대출권수_전자자료_청소년_언어','대출권수_전자자료_청소년_문학','대출권수_전자자료_청소년_역사','대출권수_전자자료_성인_총류','대출권수_전자자료_성인_철학','대출권수_전자자료_성인_종교','대출권수_전자자료_성인_사회과학','대출권수_전자자료_성인_순수과학','대출권수_전자자료_성인_기술과학','대출권수_전자자료_성인_예술','대출권수_전자자료_성인_언어','대출권수_전자자료_성인_문학','대출권수_전자자료_성인_역사']]
#2-2 이용자 분석: 나이/장르/자료별 대출권수
p21h=p21.loc[:,['상호대차의뢰및제공건수_의뢰','상호대차의뢰및제공건수_제공','정보서비스의뢰및제공_의뢰','정보서비스의뢰및제공_제공','홈페이지접속수','모바일웹접속건수','이용자 교육_오프라인_교육건수','이용자 교육_오프라인_교육시간','이용자 교육_오프라인_교육참가자수','이용자 교육_온라인_교육건수','이용자 교육_온라인_교육시간','이용자 교육_온라인_교육참가자수','오프라인_문화프로그램_강좌수_실시횟수','오프라인_문화프로그램_강좌수_참가자수','오프라인_문화프로그램_1회성프로그램_실시횟수','오프라인_문화프로그램_1회성프로그램_참가자수','오프라인_도서관및독서관련프로그램_강좌수_실시횟수','오프라인_도서관및독서관련프로그램_강좌수_참가자수','오프라인_도서관및독서관련프로그램_1회성_실시횟수','오프라인_도서관및독서관련프로그램_1회성_참가자수','온라인_문화프로그램_강좌수_실시횟수','온라인_문화프로그램_강좌수_참가자수','온라인_문화프로그램_1회성프로그램_실시횟수','온라인_문화프로그램_1회성프로그램_참가자수','온라인_도서관및독서관련프로그램_강좌수_실시횟수','온라인_도서관및독서관련프로그램_강좌수_참가자수','온라인_도서관및독서관련프로그램_1회성_실시횟수','온라인_도서관및독서관련프로그램_1회성_참가자수']]
#도서 운영프로그램 및 서비스
p21i=p21.loc[:,'도서관총예산(21년도 결산액)']

# %%
#결측치 0으로 변환
p21=p21.fillna(0)

# %% [markdown]
# - ### 데이터 결합: concat()

# %%
np21=pd.concat([p21a,p21b,p21c,p21d,p21e,p21f,p21g,p21ge,p21h,p21i],axis=1)

# %%
np20=pd.concat([p20a,p20b,p20c,p20d,p20e,p20f,p20g,p20ge,p20h,p20i],axis=1)

# %%
np19=pd.concat([p19a,p19b,p19c,p19d,p19e,p19f,p19g,p19h,p19i],axis=1)

# %%
np18=pd.concat([p18a,p18b,p18c,p18d,p18e,p18f,p18g,p18h,p18i],axis=1)

# %%
np17=pd.concat([p17a,p17b,p17c,p17d,p17e,p17f,p17g,p17h,p17i],axis=1)

# %% [markdown]
# - 결합한 데이터프레임 행열 수 확인

# %%
np21.shape
# Out:
# (1208, 154)

# %%
np20.shape
# Out:
# (1172, 154)

# %%
np19.shape
# Out:
# (1134, 108)

# %%
np18.shape
# Out:
# (1096, 108)

# %%
np17.shape
# Out:
# (1062, 108)

# %% [markdown]
# - 데이터프레임 칼럼이름 동일하게 변경

# %%
np21.columns = ['도서관명', '구분', '지역','시설_도서관부지면적','연간_총_개관일수','주당_평균_개관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인
관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인','도서관_방문자수','작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수','결산_인건비_금액(천원)','결산_인건비_비고','결산_자료구입비_금액(천원)','결산_자료구입비_비고','결산_운영비_금액(천원)','결산_운영비_비고','예산_자료구입비_도서_금액(천원)','예산_자료구입비_비도서_금액(천원)','예산_자료구입비_전자_금액(천원)','예산_자료구입비_연속_금액(천원)','예산_운영비_유지비_금액(천원)','예산_운영비_프로그램비_금액(천원)','예산_운영비_기타_금액(천원)','도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','지역_지역자료','지역_기타','비도서_시청각자료','비도서_기타','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외','대출자수_인쇄자료_어린이','대출자수_인쇄자료_청소년','대출자수_인쇄자료_성인','대출권수_인쇄자료_어린이_총류','대출권수_인쇄자료_어린이_철학','대출권수_인쇄자료_어린이_종교','대출권수_인쇄자료_어린이_사회과학','대출권수_인쇄자료_어린이_순수과학','대출권수_인쇄자료_어린이_기술과학','대출권수_인쇄자료_어린이_예술','대출권수_인쇄자료_어린이_언어','대출권수_인쇄자료_어린이_문학','대출권수_인쇄자료_어린이_역사','대출권수_인쇄자료_청소년_총류','대출권수_인쇄자료_청소년_철학','대출권수_인쇄자료_청소년_종교','대출권수_인쇄자료_청소년_사회과학','대출권수_인쇄자료_청소년_순수과학','대출권수_인쇄자료_청소년_기술과학','대출권수_인쇄자료_청소년_예술','대출권수_인쇄자료_청소년_언어','대출권수_인쇄자료_청소년_문학','대출권수_인쇄자료_청소년_역사','대출권수_인쇄자료_성인_총류','대출권수_인쇄자료_성인_철학','대출권수_인쇄자료_성인_종교','대출권수_인쇄자료_성인_사회과학','대출권수_인쇄자료_성인_순수과학','대출권수_인쇄자료_성인_기술과학','대출권수_인쇄자료_성인_예술','대출권수_인쇄자료_성인_언어','대출권수_인쇄자료_성인_문학','대출권수_인쇄자료_성인_역사','상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지_접속건수','모바일웹_접속건수','이용자교육_오프라인_건수','이용자교육_오프라인_시간','이용자교육_오프라인_참가자수','문화프로그램_오프라인_정기_강좌_건수','문화프로그램_오프라인_정기_강좌_참가자수','문화프로그램_오프라인_1회성_강좌_건수','문화프로그램_오프라인_1회성_강좌_참가자수','독서프로그램_오프라인_정기_강좌_건수','독서프로그램_오프라인_정기_강좌_참가자수','독서프로그램_오프라인_1회성_강좌_건수','독서프로그램_오프라인_1회성_강좌_참가자수','도서관총예산']

# %%
np18.columns = ['도서관명','구분','지역','시설_도서관부지면적','연간_총_개관일수','주당_평균_개관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인','도서관_방문자수','작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수','결산_인건비_금액(천원)','결산_인건비_비고','결산_자료구입비_금액(천원)','결산_자료구입비_비고','결산_운영비_금액(천원)','결산_운영비_비고','예산_자료구입비_도서_금액(천원)','예산_자료구입비_비도서_금액(천원)','예산_자료구입비_전자_금액(천원)','예산_자료구입비_연속_금액(천원)','예산_운영비_유지비_금액(천원)','예산_운영비_프로그램비_금액(천원)','예산_운영비_기타_금액(천원)','도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','지역_지역자료','지역_기타','비도서_시청각자료','비도서_기타','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외','대출자수_인쇄자료_어린이','대출자수_인쇄자료_청소년','대출자수_인쇄자료_성인','대출권수_인쇄자료_어린이_총류','대출권수_인쇄자료_어린이_철학','대출권수_인쇄자료_어린이_종교','대출권수_인쇄자료_어린이_사회과학','대출권수_인쇄자료_어린이_순수과학','대출권수_인쇄자료_어린이_기술과학','대출권수_인쇄자료_어린이_예술','대출권수_인쇄자료_어린이_언어','대출권수_인쇄자료_어린이_문학','대출권수_인쇄자료_어린이_역사','대출권수_인쇄자료_청소년_총류','대출권수_인쇄자료_청소년_철학','대출권수_인쇄자료_청소년_종교','대출권수_인쇄자료_청소년_사회과학','대출권수_인쇄자료_청소년_순수과학','대출권수_인쇄자료_청소년_기술과학','대출권수_인쇄자료_청소년_예술','대출권수_인쇄자료_청소년_언어','대출권수_인쇄자료_청소년_문학','대출권수_인쇄자료_청소년_역사','대출권수_인쇄자료_성인_총류','대출권수_인쇄자료_성인_철학','대출권수_인쇄자료_성인_종교','대출권수_인쇄자료_성인_사회과학','대출권수_인쇄자료_성인_순수과학','대출권수_인쇄자료_성인_기술과학','대출권수_인쇄자료_성인_예술','대출권수_인쇄자료_성인_언어','대출권수_인쇄자료_성인_문학','대출권수_인쇄자료_성인_역사','상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지_접속건수','모바일웹_접속건수','이용자교육_오프라인_건수','이용자교육_오프라인_시간','이용자교육_오프라인_참가자수','문화프로그램_오프라인_정기_강좌_건수','문화프로그램_오프라인_정기_강좌_참가자수','문화프로그램_오프라인_1회성_강좌_건수','문화프로그램_오프라인_1회성_강좌_참가자수','독서프로그램_오프라인_정기_강좌_건수','독서프로그램_오프라인_정기_강좌_참가자수','독서프로그램_오프라인_1회성_강좌_건수','독서프로그램_오프라인_1회성_강좌_참가자수','도서관총예산']

# %%
np17.columns = ['도서관명','구분','지역','시설_도서관부지면적','연간_총_개관일수','주당_평균_개관시간','회원등록자수_어린이','회원등록자수_청소년','회원등록자수_성인','도서관_방문자수','작은_도서관수','작은_인력수','작은_예산액','작은_장서수','작은_프로그램수','결산_인건비_금액(천원)','결산_인건비_비고','결산_자료구입비_금액(천원)','결산_자료구입비_비고','결산_운영비_금액(천원)','결산_운영비_비고','예산_자료구입비_도서_금액(천원)','예산_자료구입비_비도서_금액(천원)','예산_자료구입비_전자_금액(천원)','예산_자료구입비_연속_금액(천원)','예산_운영비_유지비_금액(천원)','예산_운영비_프로그램비_금액(천원)','예산_운영비_기타_금액(천원)','도서_국내_총류','도서_국내_철학','도서_국내_종교','도서_국내_사회과학','도서_국내_순수과학','도서_국내_기술과학','도서_국내_예술','도서_국내_언어','도서_국내_문학','도서_국내_역사','도서_국외_총류','도서_국외_철학','도서_국외_종교','도서_국외_사회과학','도서_국외_순수과학','도서_국외_기술과학','도서_국외_예술','도서_국외_언어','도서_국외_문학','도서_국외_역사','지역_지역자료','지역_기타','비도서_시청각자료','비도서_기타','전자자료_전자저널','전자자료_전자도서','전자자료_기타','연속간행물_국내','연속간행물_국외','대출자수_인쇄자료_어린이','대출자수_인쇄자료_청소년','대출자수_인쇄자료_성인','대출권수_인쇄자료_어린이_총류','대출권수_인쇄자료_어린이_철학','대출권수_인쇄자료_어린이_종교','대출권수_인쇄자료_어린이_사회과학','대출권수_인쇄자료_어린이_순수과학','대출권수_인쇄자료_어린이_기술과학','대출권수_인쇄자료_어린이_예술','대출권수_인쇄자료_어린이_언어','대출권수_인쇄자료_어린이_문학','대출권수_인쇄자료_어린이_역사','대출권수_인쇄자료_청소년_총류','대출권수_인쇄자료_청소년_철학','대출권수_인쇄자료_청소년_종교','대출권수_인쇄자료_청소년_사회과학','대출권수_인쇄자료_청소년_순수과학','대출권수_인쇄자료_청소년_기술과학','대출권수_인쇄자료_청소년_예술','대출권수_인쇄자료_청소년_언어','대출권수_인쇄자료_청소년_문학','대출권수_인쇄자료_청소년_역사','대출권수_인쇄자료_성인_총류','대출권수_인쇄자료_성인_철학','대출권수_인쇄자료_성인_종교','대출권수_인쇄자료_성인_사회과학','대출권수_인쇄자료_성인_순수과학','대출권수_인쇄자료_성인_기술과학','대출권수_인쇄자료_성인_예술','대출권수_인쇄자료_성인_언어','대출권수_인쇄자료_성인_문학','대출권수_인쇄자료_성인_역사','상호대차_의뢰','상호대차_제공','정보서비스_의뢰','정보서비스_제공','홈페이지_접속건수','모바일웹_접속건수','이용자교육_오프라인_건수','이용자교육_오프라인_시간','이용자교육_오프라인_참가자수','문화프로그램_오프라인_정기_강좌_건수','문화프로그램_오프라인_정기_강좌_참가자수','문화프로그램_오프라인_1회성_강좌_건수','문화프로그램_오프라인_1회성_강좌_참가자수','독서프로그램_오프라인_정기_강좌_건수','독서프로그램_오프라인_정기_강좌_참가자수','독서프로그램_오프라인_1회성_강좌_건수','독서프로그램_오프라인_1회성_강좌_참가자수','도서관총예산']

# %% [markdown]
# - 결측치 유무 체크

# %%
np21.isnull().sum().sum()
# Out:
# 29727

# %%
np21=np21.fillna(0)

# %%
np21.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - 1차 처리된 데이터 추출

# %%
np21.to_excel('data/pub21_전처리(완).xlsx')

# %%
np20.to_excel('data/pub20_전처리(완).xlsx')
np19.to_excel('data/pub19_전처리(완).xlsx')
np18.to_excel('data/pub18_전처리(완).xlsx')
np17.to_excel('data/pub17_전처리(완).xlsx')
